# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabirsaudagar/Kabirsaudagar/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Read temperature in Celsius from the user
celsius = float(input("Enter temperature in Celsius: "))

# Convert to Fahrenheit and Kelvin
fahrenheit = (celsius * 9/5) + 32
kelvin = celsius + 273.15

# Display the results
print(f"{celsius}°C is equal to {fahrenheit:.2f}°F")
print(f"{celsius}°C is equal to {kelvin:.2f}K")
# Out:
# Enter temperature in Celsius: 23
# 23.0°C is equal to 73.40°F
# 23.0°C is equal to 296.15K
