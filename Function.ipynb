# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabirsaudagar/Kabirsaudagar/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 def greet():
  print("welcome to python")
greet()
greet()
# Out:
# welcome to python
# welcome to python

# %%
def greet():
  print("Welcome to function programming")
greet()
# Out:
# Welcome to function programming

# %%
def sum3(3, 6, 2)
print("Sum of numbers are:", 3 + 6 + 2)
sum3(3, 6, 2):
# Out:
#   File "/tmp/ipykernel_1707/4246108777.py", line 1
#     def sum3(3, 6, 2)
#              ^
# SyntaxError: invalid syntax
