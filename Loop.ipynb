# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabirsaudagar/Kabirsaudagar/blob/main/Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
    print(i)

for i in range(2, 10, 2):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 8

# %%
items = ["Rice", "Milk", "Bread"]
prices = [50, 40, 30]
for i in range(len(items)):
    print(items[i], "-> Rs.", prices[i])
# Out:
# Rice -> Rs. 50
# Milk -> Rs. 40
# Bread -> Rs. 30
