# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabirsaudagar/Kabirsaudagar/blob/main/Code2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
age= 20
if age >= 18:
    print("You are eligible to vote")

print("Program finished")
# Out:
# You are eligible to vote
# Program finished

# %%
#if-else statement

marks= 35

if marks >= 35:
    print("You have passed")
else:
    print("You have failed")
# Out:
# You have passed

# %%
#if-elif-else statement
marks= 75

if marks>= 90:
   print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 45:
    print("Grade D")
else:
     print("Grade F")
# Out:
# Grade B

# %%
#for loop with range()
for i in range(5):
  print(i)

for i in range(2, 10, 2):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 8

# %%
count= 1

while count <= 5:
  print("Count is", count)
  count= count + 1
# Out:
# Count is 1
# Count is 2
# Count is 3
# Count is 4
# Count is 5

# %%
for i in range (3):
  for j in range(2):
   print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
rows = 4
for i in range(1, rows + 1):
  for j in range(i):
     print("*",end="")
print()
# Out:
# **********

# %%
for i in range(5):
     print(i)
else:
  print:("End of the Loop")
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
age= 20
status= "Adult" if age >= 18 else "Child"
print(status)
# Out:
# Adult
